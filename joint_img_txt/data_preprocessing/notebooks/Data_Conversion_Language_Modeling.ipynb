# %% [markdown]
# # Deal with writing a csv file for the language modeling for radiology reports

# %% [markdown]
# Author: Geeticka Chauhan

# %%
# %load_ext autoreload

# %% [markdown]
# Requirements:
# Make sure to `pip install spacy`
# and `pip install scispacy` with the relevant model being en_core_sci_md from `https://allenai.github.io/scispacy/`

# %%
# %autoreload

import os
import sys
sys.path.append('../..')
import pandas as pd
import joint_img_txt.data.text.lm_utils as lm_utils
import re
import joint_img_txt.data.text.preprocess as preprocess

import glob
from tqdm import tqdm
import re
from pyexpat import ExpatError

in_dir = '/data/vision/polina/projects/chestxray/data_v2/reports/' 
# Replace the above with the location of MIMIC-CXR .txt reports
out_dir = '/data/vision/polina/projects/chestxray/geeticka/pre-processed/' 
# Replace the above with the output directory for where you would like the csv file of all reports located
# this is where the outputted csv files will be located inside the directory reports_list/

def in_res(filename): return os.path.join(in_dir, filename)
def out_res(filename): return os.path.join(out_dir, filename)
if not os.path.exists(out_dir):
    os.mkdir(out_dir)
if not os.path.exists(out_res('lm_reports')):
    os.mkdir(out_res('lm_reports'))

# %%
reports_df = lm_utils.get_reports_df(in_dir)
# Out:
# Total files to read: 224672  from dir:  /data/vision/polina/projects/chestxray/data_v2/reports/
# HBox(children=(IntProgress(value=0, max=224672), HTML(value='')))
# File s51431102.txt involves appending to the dictionary value list
# File s58090273.txt involves appending to the dictionary value list
# File s51966946.txt has importance sections empty and following section with too many space
# File s51966946.txt involves appending to the dictionary value list
# File s52762865.txt involves appending to the dictionary value list
# File s59385570.txt has importance sections empty and following section with too many space
# File s59385570.txt involves appending to the dictionary value list
# File s59420146.txt has importance sections empty and following section with too many space
# File s59420146.txt involves appending to the dictionary value list
# File s50106655.txt has importance sections empty and following section with too many space
# File s50106655.txt involves appending to the dictionary value list
# File s57295412.txt involves appending to the dictionary value list
# File s57350021.txt has importance sections empty and following section with too many space
# File s57350021.txt involves appending to the dictionary value list
# File s52512533.txt involves appending to the dictionary value list
# File s51203766.txt involves appending to the dictionary value list
# File s53641589.txt involves appending to the dictionary value list
# File s54993044.txt involves appending to the dictionary value list
# File s54993044.txt involves appending to the dictionary value list
# File s51098672.txt involves appending to the dictionary value list
# File s59272538.txt involves appending to the dictionary value list
# File s57784081.txt involves appending to the dictionary value list
# File s58869833.txt has importance sections empty and following section with too many space
# File s58869833.txt involves appending to the dictionary value list
# File s56499934.txt involves appending to the dictionary value list
# File s56499934.txt involves appending to the dictionary value list
# File s56499934.txt involves appending to the dictionary value list
# File s56499934.txt involves appending to the dictionary value list
# File s56499934.txt involves appending to the dictionary value list
# File s56499934.txt involves appending to the dictionary value list
# File s56499934.txt involves appending to the dictionary value list
# Line FINDINGS and IMPRESSION in file s57072757.txt has both section names ['FINDING', 'IMPRESSION']
# Line FINDINGS and IMPRESSION in file s57072757.txt has both section names ['FINDING', 'IMPRESSION']
# Line FINDINGS and IMPRESSION in file s57072757.txt has both section names ['FINDING', 'IMPRESSION']
# File s56309748.txt involves appending to the dictionary value list
# File s50698424.txt has importance sections empty and following section with too many space
# File s50698424.txt involves appending to the dictionary value list
# File s51834819.txt involves appending to the dictionary value list
# File s53690219.txt has importance sections empty and following section with too many space
# File s53690219.txt involves appending to the dictionary value list
# File s52765578.txt involves appending to the dictionary value list
# File s52099738.txt has importance sections empty and following section with too many space
# File s52099738.txt involves appending to the dictionary value list
# File s53224853.txt involves appending to the dictionary value list
# File s51516320.txt involves appending to the dictionary value list
# File s51037712.txt involves appending to the dictionary value list
# File s56627828.txt has importance sections empty and following section with too many space
# File s56627828.txt involves appending to the dictionary value list
# Line IMPRESSION: FINDINGS:A in file s54475003.txt has both section names ['FINDING', 'IMPRESSION']
# Line IMPRESSION: FINDINGS:A in file s54475003.txt has both section names ['FINDING', 'IMPRESSION']
# Line IMPRESSION: FINDINGS:A in file s54475003.txt has both section names ['FINDING', 'IMPRESSION']
# File s57972534.txt involves appending to the dictionary value list
# File s59988068.txt involves appending to the dictionary value list
# Line IMPRESSION: FINDINGS: in file s56509801.txt has both section names ['FINDING', 'IMPRESSION']
# Line IMPRESSION: FINDINGS: in file s56509801.txt has both section names ['FINDING', 'IMPRESSION']
# Line IMPRESSION: FINDINGS: in file s56509801.txt has both section names ['FINDING', 'IMPRESSION']
# File s51579976.txt involves appending to the dictionary value list
# Line IMPRESSION: FINDINGS: in file s51485529.txt has both section names ['FINDING', 'IMPRESSION']
# Line IMPRESSION: FINDINGS: in file s51485529.txt has both section names ['FINDING', 'IMPRESSION']
# Line IMPRESSION: FINDINGS: in file s51485529.txt has both section names ['FINDING', 'IMPRESSION']
# File s53114969.txt involves appending to the dictionary value list
# File s56836104.txt involves appending to the dictionary value list
# File s56293853.txt has importance sections empty and following section with too many space
# File s56293853.txt involves appending to the dictionary value list
# File s50540395.txt involves appending to the dictionary value list
# Line FINDINGS/ IMPRESSION: There has been interval placement of an endogastric in file s52518969.txt has both section names ['FINDING', 'IMPRESSION']
# Line FINDINGS/ IMPRESSION: There has been interval placement of an endogastric in file s52518969.txt has both section names ['FINDING', 'IMPRESSION']
# Line FINDINGS/ IMPRESSION: There has been interval placement of an endogastric in file s52518969.txt has both section names ['FINDING', 'IMPRESSION']
# File s57826733.txt has importance sections empty and following section with too many space
# File s57826733.txt involves appending to the dictionary value list
# File s54418111.txt has importance sections empty and following section with too many space
# File s54418111.txt involves appending to the dictionary value list
# File s53124067.txt involves appending to the dictionary value list
# File s53397494.txt involves appending to the dictionary value list
# File s58546811.txt has importance sections empty and following section with too many space
# File s58546811.txt involves appending to the dictionary value list
# File s53467166.txt involves appending to the dictionary value list
# File s59586863.txt has importance sections empty and following section with too many space
# File s59586863.txt involves appending to the dictionary value list
# File s55440465.txt has importance sections empty and following section with too many space
# File s55440465.txt involves appending to the dictionary value list
# File s54473369.txt involves appending to the dictionary value list
# File s54473369.txt involves appending to the dictionary value list
# Line FINDINGS and IMPRESSION in file s58307570.txt has both section names ['FINDING', 'IMPRESSION']
# Line FINDINGS and IMPRESSION in file s58307570.txt has both section names ['FINDING', 'IMPRESSION']
# Line FINDINGS and IMPRESSION in file s58307570.txt has both section names ['FINDING', 'IMPRESSION']
# File s51634013.txt has importance sections empty and following section with too many space
# File s51634013.txt involves appending to the dictionary value list
# File s51591636.txt involves appending to the dictionary value list
# File s54408403.txt involves appending to the dictionary value list
# File s51369728.txt involves appending to the dictionary value list
# File s52746159.txt involves appending to the dictionary value list
# File s50573874.txt has importance sections empty and following section with too many space
# File s50573874.txt involves appending to the dictionary value list
# File s56553720.txt involves appending to the dictionary value list
# File s56673350.txt involves appending to the dictionary value list
# File s56176907.txt involves appending to the dictionary value list
# File s56770244.txt involves appending to the dictionary value list
# File s56127322.txt involves appending to the dictionary value list
# File s55130254.txt involves appending to the dictionary value list
# File s51872856.txt involves appending to the dictionary value list
# The file s54168089.txt is empty
# File s50902543.txt involves appending to the dictionary value list
# File s55693339.txt involves appending to the dictionary value list
# File s55945369.txt has importance sections empty and following section with too many space
# File s55945369.txt involves appending to the dictionary value list
# File s53747822.txt has importance sections empty and following section with too many space
# File s53747822.txt involves appending to the dictionary value list
# File s57319606.txt involves appending to the dictionary value list
# File s50058765.txt involves appending to the dictionary value list
# File s50833007.txt involves appending to the dictionary value list
# File s50269150.txt involves appending to the dictionary value list
# File s53072658.txt has importance sections empty and following section with too many space
# File s53072658.txt involves appending to the dictionary value list
# File s57387939.txt involves appending to the dictionary value list
# File s53649363.txt has importance sections empty and following section with too many space
# File s53649363.txt involves appending to the dictionary value list
# File s53245159.txt involves appending to the dictionary value list
# File s55346214.txt involves appending to the dictionary value list
# File s50835258.txt involves appending to the dictionary value list
# File s51479531.txt involves appending to the dictionary value list
# File s50993229.txt involves appending to the dictionary value list
# File s57185498.txt involves appending to the dictionary value list
# File s54064897.txt involves appending to the dictionary value list
# File s57458569.txt involves appending to the dictionary value list
# File s57458569.txt involves appending to the dictionary value list
# File s56310607.txt involves appending to the dictionary value list
# File s53089879.txt involves appending to the dictionary value list
# File s53112065.txt involves appending to the dictionary value list
# File s57327711.txt involves appending to the dictionary value list
# File s51813550.txt involves appending to the dictionary value list
# File s57541620.txt has importance sections empty and following section with too many space
# File s57541620.txt involves appending to the dictionary value list
# File s53647598.txt involves appending to the dictionary value list
# File s55950375.txt has importance sections empty and following section with too many space
# File s55950375.txt involves appending to the dictionary value list
# File s52937109.txt involves appending to the dictionary value list
# File s50217390.txt involves appending to the dictionary value list
# File s57060458.txt has importance sections empty and following section with too many space
# File s57060458.txt involves appending to the dictionary value list
# File s53880133.txt involves appending to the dictionary value list
# File s55802264.txt involves appending to the dictionary value list
# File s53627504.txt involves appending to the dictionary value list
# File s53627504.txt involves appending to the dictionary value list
# File s53627504.txt involves appending to the dictionary value list
# File s53627504.txt involves appending to the dictionary value list
# File s53627504.txt involves appending to the dictionary value list
# File s53627504.txt involves appending to the dictionary value list
# File s53627504.txt involves appending to the dictionary value list
# File s53627504.txt involves appending to the dictionary value list
# File s53627504.txt involves appending to the dictionary value list
# File s53627504.txt involves appending to the dictionary value list
# File s56022717.txt involves appending to the dictionary value list
# File s59623682.txt involves appending to the dictionary value list
# File s54537817.txt involves appending to the dictionary value list
# File s56598615.txt involves appending to the dictionary value list
# File s59821191.txt involves appending to the dictionary value list
# File s59821191.txt involves appending to the dictionary value list
# File s59821191.txt involves appending to the dictionary value list
# File s55837995.txt has importance sections empty and following section with too many space
# File s55837995.txt involves appending to the dictionary value list
# File s58609582.txt involves appending to the dictionary value list
# File s50097105.txt has importance sections empty and following section with too many space
# File s50097105.txt involves appending to the dictionary value list
# File s57398211.txt involves appending to the dictionary value list
# File s55639385.txt has importance sections empty and following section with too many space
# File s55639385.txt involves appending to the dictionary value list
# File s55037560.txt involves appending to the dictionary value list
# File s58292533.txt involves appending to the dictionary value list
# File s59865391.txt involves appending to the dictionary value list
# File s51188807.txt involves appending to the dictionary value list
# File s55903865.txt involves appending to the dictionary value list
# File s52352541.txt involves appending to the dictionary value list
# File s58346606.txt involves appending to the dictionary value list
# File s55006481.txt involves appending to the dictionary value list
# File s59185554.txt has importance sections empty and following section with too many space
# File s59185554.txt involves appending to the dictionary value list
# File s58438388.txt has importance sections empty and following section with too many space
# File s58438388.txt involves appending to the dictionary value list
# File s56429302.txt involves appending to the dictionary value list
# File s50336284.txt has importance sections empty and following section with too many space
# File s50336284.txt involves appending to the dictionary value list
# File s55220508.txt involves appending to the dictionary value list
# File s51438931.txt involves appending to the dictionary value list
# File s59458698.txt involves appending to the dictionary value list
# File s51472417.txt involves appending to the dictionary value list
# File s57544668.txt has importance sections empty and following section with too many space
# File s57544668.txt involves appending to the dictionary value list
# File s58561639.txt has importance sections empty and following section with too many space
# File s58561639.txt involves appending to the dictionary value list
# File s58210288.txt involves appending to the dictionary value list
# File s57300677.txt involves appending to the dictionary value list
# File s51704764.txt has importance sections empty and following section with too many space
# File s51704764.txt involves appending to the dictionary value list
# File s55653211.txt has importance sections empty and following section with too many space
# File s55653211.txt involves appending to the dictionary value list
# File s59943404.txt involves appending to the dictionary value list
# File s53058613.txt involves appending to the dictionary value list
# File s50581205.txt has importance sections empty and following section with too many space
# File s50581205.txt involves appending to the dictionary value list
# File s51035496.txt has importance sections empty and following section with too many space
# File s51035496.txt involves appending to the dictionary value list
# File s57295780.txt involves appending to the dictionary value list
# File s53896964.txt involves appending to the dictionary value list
# File s57008187.txt involves appending to the dictionary value list
# Line IMPRESSION: FINDINGS: in file s51017605.txt has both section names ['FINDING', 'IMPRESSION']
# Line IMPRESSION: FINDINGS: in file s51017605.txt has both section names ['FINDING', 'IMPRESSION']
# Line IMPRESSION: FINDINGS: in file s51017605.txt has both section names ['FINDING', 'IMPRESSION']
# File s58952588.txt involves appending to the dictionary value list
# File s54057705.txt involves appending to the dictionary value list
# File s50804446.txt has importance sections empty and following section with too many space
# File s50804446.txt involves appending to the dictionary value list
# File s56334409.txt involves appending to the dictionary value list
# File s50016489.txt has importance sections empty and following section with too many space
# File s50016489.txt involves appending to the dictionary value list
# File s57928128.txt has importance sections empty and following section with too many space
# File s57928128.txt involves appending to the dictionary value list
# File s54808257.txt involves appending to the dictionary value list
# File s51394967.txt has importance sections empty and following section with too many space
# File s51394967.txt involves appending to the dictionary value list
# File s58067260.txt involves appending to the dictionary value list
# File s57271119.txt involves appending to the dictionary value list
# File s54346445.txt involves appending to the dictionary value list
# File s54346445.txt involves appending to the dictionary value list
# File s56274071.txt involves appending to the dictionary value list
# File s57595015.txt involves appending to the dictionary value list
# File s58501303.txt involves appending to the dictionary value list
# File s54407986.txt has importance sections empty and following section with too many space
# File s54407986.txt involves appending to the dictionary value list
# File s54977408.txt involves appending to the dictionary value list
# File s55285472.txt has importance sections empty and following section with too many space
# File s55285472.txt involves appending to the dictionary value list
# File s58141654.txt has importance sections empty and following section with too many space
# File s58141654.txt involves appending to the dictionary value list
# File s59479076.txt involves appending to the dictionary value list
# File s52501959.txt has importance sections empty and following section with too many space
# File s52501959.txt involves appending to the dictionary value list
# File s54771599.txt involves appending to the dictionary value list
# File s53356173.txt involves appending to the dictionary value list
# File s56701415.txt involves appending to the dictionary value list
# File s54122362.txt has importance sections empty and following section with too many space
# File s54122362.txt involves appending to the dictionary value list
# File s51829135.txt has importance sections empty and following section with too many space
# File s51829135.txt involves appending to the dictionary value list
# File s50025176.txt involves appending to the dictionary value list
# File s50611186.txt involves appending to the dictionary value list
# File s50611186.txt involves appending to the dictionary value list
# File s52216281.txt has importance sections empty and following section with too many space
# File s52216281.txt involves appending to the dictionary value list
# File s58540737.txt involves appending to the dictionary value list
# File s54128617.txt involves appending to the dictionary value list
# File s56643259.txt has importance sections empty and following section with too many space
# File s56643259.txt involves appending to the dictionary value list
# File s52323653.txt involves appending to the dictionary value list
# File s52323653.txt involves appending to the dictionary value list
# File s59028564.txt involves appending to the dictionary value list
# File s54523381.txt involves appending to the dictionary value list
# File s58441499.txt involves appending to the dictionary value list
# File s59564965.txt involves appending to the dictionary value list
# File s50336360.txt involves appending to the dictionary value list
# File s56206754.txt involves appending to the dictionary value list
# File s59455707.txt has importance sections empty and following section with too many space
# File s59455707.txt involves appending to the dictionary value list
# File s58171623.txt involves appending to the dictionary value list
# File s57319256.txt involves appending to the dictionary value list
# File s56581687.txt has importance sections empty and following section with too many space
# File s56581687.txt involves appending to the dictionary value list
# File s58249247.txt involves appending to the dictionary value list
# File s54631370.txt involves appending to the dictionary value list
# File s55167618.txt involves appending to the dictionary value list
# File s59547556.txt involves appending to the dictionary value list
# File s56307284.txt involves appending to the dictionary value list
# File s59159499.txt has importance sections empty and following section with too many space
# File s59159499.txt involves appending to the dictionary value list
# File s52575467.txt has importance sections empty and following section with too many space
# File s52575467.txt involves appending to the dictionary value list
# File s52850423.txt has importance sections empty and following section with too many space
# File s52850423.txt involves appending to the dictionary value list
# File s59499427.txt involves appending to the dictionary value list
# File s58851430.txt has importance sections empty and following section with too many space
# File s58851430.txt involves appending to the dictionary value list
# File s57806255.txt involves appending to the dictionary value list
# File s58015737.txt involves appending to the dictionary value list
# File s52745685.txt involves appending to the dictionary value list
# File s52671410.txt has importance sections empty and following section with too many space
# File s52671410.txt involves appending to the dictionary value list
# File s59052974.txt has importance sections empty and following section with too many space
# File s59052974.txt involves appending to the dictionary value list
# File s50180451.txt involves appending to the dictionary value list
# File s57762365.txt involves appending to the dictionary value list
# File s57844688.txt involves appending to the dictionary value list
# File s55303433.txt involves appending to the dictionary value list
# File s55502141.txt involves appending to the dictionary value list
# File s52438350.txt has importance sections empty and following section with too many space
# File s52438350.txt involves appending to the dictionary value list
# File s57050708.txt has importance sections empty and following section with too many space
# File s57050708.txt involves appending to the dictionary value list
# File s56123818.txt involves appending to the dictionary value list
# File s55460408.txt has importance sections empty and following section with too many space
# File s55460408.txt involves appending to the dictionary value list
# File s57600823.txt involves appending to the dictionary value list
# File s57600823.txt involves appending to the dictionary value list
# File s54560220.txt involves appending to the dictionary value list
# File s50709283.txt has importance sections empty and following section with too many space
# File s50709283.txt involves appending to the dictionary value list
# File s55968462.txt involves appending to the dictionary value list
# File s55968462.txt involves appending to the dictionary value list
# File s55968462.txt involves appending to the dictionary value list
# File s55968462.txt involves appending to the dictionary value list
# File s55968462.txt involves appending to the dictionary value list
# File s55968462.txt involves appending to the dictionary value list
# File s55968462.txt involves appending to the dictionary value list
# File s55968462.txt involves appending to the dictionary value list
# File s55968462.txt involves appending to the dictionary value list
# File s55968462.txt involves appending to the dictionary value list
# File s57531913.txt involves appending to the dictionary value list
# File s52147430.txt involves appending to the dictionary value list
# File s56753538.txt involves appending to the dictionary value list
# File s59930730.txt involves appending to the dictionary value list
# File s59287139.txt involves appending to the dictionary value list
# File s55204744.txt has importance sections empty and following section with too many space
# File s55204744.txt involves appending to the dictionary value list
# File s59363654.txt involves appending to the dictionary value list
# File s59710801.txt involves appending to the dictionary value list
# File s50674976.txt involves appending to the dictionary value list
# File s50537048.txt involves appending to the dictionary value list
# File s50660584.txt involves appending to the dictionary value list
# File s50227704.txt involves appending to the dictionary value list
# File s51728823.txt involves appending to the dictionary value list
# File s54180204.txt involves appending to the dictionary value list
# File s59665863.txt involves appending to the dictionary value list
# File s56924594.txt has importance sections empty and following section with too many space
# File s56924594.txt involves appending to the dictionary value list
# File s56796696.txt has importance sections empty and following section with too many space
# File s56796696.txt involves appending to the dictionary value list
# File s51850376.txt involves appending to the dictionary value list
# File s53590982.txt involves appending to the dictionary value list
# File s59281202.txt has importance sections empty and following section with too many space
# File s59281202.txt involves appending to the dictionary value list
# File s53718151.txt involves appending to the dictionary value list
# File s59698776.txt involves appending to the dictionary value list
# File s54374353.txt has importance sections empty and following section with too many space
# File s54374353.txt involves appending to the dictionary value list
# File s55486770.txt involves appending to the dictionary value list

# %%
lm_utils.write_dataframe(reports_df, out_res('lm_reports/original_reports.csv'))

# %%
reports_df_copy = lm_utils.read_dataframe(out_res('lm_reports/original_reports.csv'))

# %% [markdown]
# Double check if the reports read from csv is the same as that written to disk previously. For sanity checking.

# %%
lm_utils.check_equality_of_written_and_read_df(reports_df, reports_df_copy)
# Out:
# (True, True)

# %% [markdown]
# # The following sections are optional, and may help you explore MIMIC-CXR reports further. This helped me make the code to process the reports more accurate.

# %% [markdown]
# ## Let's look at how many keys (i.e. report section headings) are possible

# %%
keys = []
for row, val in original_reports_df.iterrows():
    if type(val['report']['final_report']) is not str:
        keys.extend(list(val['report']['final_report'].keys()))

# %%
set(keys)
# Out:
# {']history',
#  ']impression',
#  'abdomen',
#  'abdomenchest',
#  'abnormal',
#  'above_the_hemidiaphragm_with_mass_effect',
#  'absence_of_any_prior_chest_imaging',
#  'accession_number',
#  'acute_cardriopulm_diseaase_surg',
#  'acute_pathology_surg',
#  'addendum',
#  'addendum_the_correct_report_should_read_as_follows',
#  'additional_clinical_history_provided',
#  'additional_findings',
#  'again_demonstrated_are',
#  'air',
#  'all_worsened_since_deid_are',
#  'allowing_for_these_limitations',
#  'ambulation_issues_surg',
#  'and_read',
#  'anesthesia',
#  'answered',
#  'any_acute_intrapulmonary_process_surg',
#  'ap',
#  'ap_and_lateral_chest_radiograph',
#  'ap_and_lateral_chest_radiographs',
#  'ap_and_lateral_radiographs_of_the_chest',
#  'ap_and_lateral_views_of_the_chest',
#  'ap_chest',
#  'ap_chest_at_deid_and_compared_to_deid_for',
#  'ap_chest_radiograph',
#  'ap_chest_reviewed_in_the_absence_of_prior_chest_imaging',
#  'ap_chest_reviewed_in_the_absence_of_prior_chest_radiographs',
#  'ap_film',
#  'ap_frontal_and_lateral_chest_radiographs',
#  'ap_frontal_chest_radiograph',
#  'ap_portable_chest',
#  'ap_portable_chest_radiograph',
#  'ap_portable_frontal_chest_radiograph',
#  'ap_portable_supine_chest_radiograph',
#  'ap_portable_upright_chest',
#  'ap_portable_upright_chest_radiograph',
#  'ap_portable_view_of_the_chest',
#  'ap_radiograph_of_the_chest',
#  'ap_supine_chest_radiograph',
#  'ap_supine_portable_chest_radiograph',
#  'ap_upright_and_lateral_chest_radiographs',
#  'ap_upright_and_lateral_views_of_the_chest',
#  'ap_upright_chest_radiograph',
#  'ap_upright_portable_chest',
#  'ap_upright_portable_chest_radiograph',
#  'ap_upright_view_of_the_chest',
#  'ap_upright_views_of_the_chest_during_inspiration_and_expiration',
#  'ap_view_and_lateral_view_of_the_chest',
#  'ap_view_of_chest',
#  'ap_view_of_the_chest',
#  'ap_views_of_the_chest',
#  'apinct_abd',
#  'arison',
#  'as_compared_to_the_previous_radiograph',
#  'as_well_as_presence_of_the_subcutaneous_air',
#  'assess_for_interval_changepneumonia_surg',
#  'assess_interval_cahgne_in_effusion',
#  'assess_position_of_ng_tube',
#  'available_at_the_time_of_this_review_shows_that_that_has_been_achieved',
#  'baseline_study_in_unstable_patient_surg',
#  'bedside_ap_radiograph_of_the_chest',
#  'bedside_ap_upright_radiograph_of_the_chest',
#  'bedside_frontal_chest_radiograph',
#  'bedside_upright_frontal_chest_radiograph',
#  'below_the_diaphragm_terminating',
#  'between_deid_and_deid_there_were_the_following_changes',
#  'bka_surg',
#  'bleedmasscxr',
#  'bone_windows',
#  'bony_thorax',
#  'brain_bx_on_deid_surg',
#  'cardiac_surgery_contact_name',
#  'cardiomegaly_ct_head',
#  'cardiopulm_process_surg',
#  'cardiopulmonary_pathology_surg',
#  'cardiopulmonary_process_surg',
#  'cardiopulmonary_surveillance_surg',
#  'cardiothoracic_process_surg',
#  'catheters_with_minimal',
#  'cc',
#  'change',
#  'change_noted_previous_read_re',
#  'change_surg',
#  'chest',
#  'chest_and_pelvis_films',
#  'chest_and_upper_abdomen',
#  'chest_ap',
#  'chest_ap_portable',
#  'chest_ap_supine',
#  'chest_comparison_film',
#  'chest_ct',
#  'chest_ct_performed_one_hour_later',
#  'chest_ct_two_views',
#  'chest_history',
#  'chest_imaging',
#  'chest_pa',
#  'chest_pa_and_lat_radiograph',
#  'chest_pa_and_lateral',
#  'chest_pa_and_lateral_radiograph',
#  'chest_portable',
#  'chest_portable_view',
#  'chest_radiograph',
#  'chest_radiographs',
#  'chest_single_view',
#  'chest_supine',
#  'chest_two_views',
#  'chestabdomen_radiographs',
#  'chestap',
#  'chin_is_elevated',
#  'cleared_and_most_likely_was_atelectatic',
#  'clincal_history',
#  'clincal_indication',
#  'clinic_indication',
#  'clinical_history',
#  'clinical_history_history',
#  'clinical_indication',
#  'clinical_information',
#  'coclusion',
#  'collection',
#  'comaprison',
#  'comment',
#  'comments',
#  'common',
#  'companion',
#  'compare',
#  'comparision',
#  'comparison',
#  'comparison_chest',
#  'comparison_comparison',
#  'comparison_exam',
#  'comparison_exams',
#  'comparison_film',
#  'comparison_films',
#  'comparison_studies',
#  'comparison_study',
#  'comparison_to_prior_study',
#  'comparisons',
#  'comparsion',
#  'compressing',
#  'concerning_for_two_abnormalities_potentially_developing_simultaneously',
#  'conclusion',
#  'conclusion-large',
#  'conclusion-no',
#  'conclusion.normal',
#  'confirm_picc_line_placement_surg',
#  'congestio_surg',
#  'conlcusion',
#  'consolidationct',
#  'consolidationct_ap',
#  'consolidationct_head',
#  'consolidationct_headneck',
#  'consolidationcta',
#  'consolidationhead_ct',
#  'contact_name',
#  'contrast',
#  'cor',
#  'coughfatiguebibasilar_deid_wdecr_bs_dull_bibasilar_pna',
#  'ct',
#  'ct_abd',
#  'ct_abdomen_pelvis',
#  'ct_chest',
#  'ct_head',
#  'cta_chest',
#  'cta_torso',
#  'currently_available',
#  'currently_seen',
#  'cxr',
#  'cxr_surg',
#  'date',
#  'date_of_exam',
#  'debridement_deid_surg',
#  'dedicated_views_of_the_right_ribs',
#  'determine_rue_picc_tip_location_prior_to_use_surg',
#  'diagnosis_still_includes',
#  'discussed_with_the_medical_team',
#  'disease_surg',
#  'dobhoff_tube_placement_r_nare_contact_name',
#  'double_chest_radiograph',
#  'downward',
#  'due_to_a_thyroid_or_other_mass',
#  'earlier',
#  'edema_surg',
#  'effectively',
#  'effusion',
#  'effusion_surg',
#  'elsewhere_earlier_in_the_day',
#  'embolectomy_surg',
#  'embolization_of_cerebral_aneurysm_surg',
#  'engorgement',
#  'enough',
#  'et_tube_and_left_subclavian_line_are_in_standard_placements_respectively',
#  'eval_for_acute_cardiopulm_process_surg',
#  'eval_for_acute_processnchct',
#  'eval_for_any_acute_cardiothoracic_process_surg',
#  'eval_for_consolidationct_head',
#  'eval_for_consolidationruq',
#  'eval_for_dvtcxr',
#  'eval_for_infarctr_leni',
#  'eval_lungcardiac_surg',
#  'eval_surg',
#  'evaluate_for_any_infectious_process_prior_to_or_surg',
#  'evaluate_for_pna_and_pulmonary_edema_surg',
#  'evaluate_for_pulmonary_changes_surg',
#  'evaluate_for_rib_fracturesct',
#  'evaluate_surg',
#  'evaluation_of_bilateral_shoulders_surg',
#  'evaluation_surg',
#  'exam',
#  'examination',
#  'except_for_lower_lung_volumes_there_is_no_new_infiltrate',
#  'expanding_massesct_neck',
#  'fidings',
#  'fimpression',
#  'final',
#  'findgings',
#  'findigns',
#  'findindgs',
#  'finding',
#  'findings',
#  'findings_and_impression',
#  'findings_and_imrpession',
#  'findings_impression',
#  'findingsimpression',
#  'findingsl',
#  'findins',
#  'findngs',
#  'findnings',
#  'findoings',
#  'fingdings',
#  'finidngs',
#  'finsings',
#  'fluoroscopy_time_and_dose',
#  'flush_contact_name',
#  'following_was_recommended',
#  'for',
#  'for_acute_inj_history',
#  'for_acute_processct_ap',
#  'for_acute_processus',
#  'for_increased_respiratory_effort',
#  'for_infiltrate_surg',
#  'for_infiltratesleni_rle',
#  'for_iv_access_surg',
#  'for_or_surg',
#  'for_palat_surg',
#  'for_pneumonia',
#  'for_possible_pulmonary_process',
#  'for_pulmonary_process_surg',
#  'for_surgery_and_tube_an_dline_placement_surg',
#  'for_v',
#  'from_deid_technique',
#  'fronal_and_lateral_views_of_the_chest',
#  'frontal_and_lateral_chest',
#  'frontal_and_lateral_chest_radiograph',
#  'frontal_and_lateral_chest_radiographs',
#  'frontal_and_lateral_frontal_chest_radiograph',
#  'frontal_and_lateral_radiographs',
#  'frontal_and_lateral_upright_chest_radiograph',
#  'frontal_and_lateral_views_chest',
#  'frontal_and_lateral_views_of_chest',
#  'frontal_and_lateral_views_of_the_chest',
#  'frontal_and_lateral_views_of_the_chest_in_expiration',
#  'frontal_and_lateral_views_the_chest',
#  'frontal_ap_and_lateral_chest',
#  'frontal_chest_radiograph',
#  'frontal_chest_radiograph_with_the_patient_in_supine_and_upright_positions',
#  'frontal_chest_radiographs',
#  'frontal_lateral_chest_radiograph',
#  'frontal_lateral_views_chest',
#  'frontal_portable_chest',
#  'frontal_portable_chest_radiograph',
#  'frontal_portable_supine_chest',
#  'frontal_portable_upright_chest',
#  'frontal_portable_upright_radiograph',
#  'frontal_radiograph_of_the_chest',
#  'frontal_semi_upright_portable_chest',
#  'frontal_supine_chest_radiograph',
#  'frontal_supine_portable_chest',
#  'frontal_supine_portable_view_of_the_chest',
#  'frontal_upright_portable_chest',
#  'frontal_view_of_the_chest',
#  'frontal_views_of_the_chest',
#  'h',
#  'has_an',
#  'head_ct',
#  'heart',
#  'hemidiaphragm',
#  'hepatobiliary_pathology_us_pelvictransvag',
#  'history',
#  'hx',
#  'hypoxia',
#  'ichct_abd',
#  'ichother_acute_processcxr',
#  'idication',
#  'if_the_patient_is_still_intubated',
#  'images',
#  'imaging',
#  'imperssion',
#  'impession',
#  'impresion',
#  'impression',
#  'impression.',
#  'impression;',
#  'impression_findings',
#  'impression_findingsa',
#  'impressions',
#  'impressoin',
#  'impresson',
#  'imprression',
#  'imprssion',
#  'in_comparison_to_previous_radiographs',
#  'increased_sobwheezing_surg',
#  'increased_work_of_breathing',
#  'indcation',
#  'indeterminate_nodular_density_projecting_over_the_right_upper_lobe',
#  'indication',
#  'indications',
#  'infection',
#  'injurycxr',
#  'interpreted_in_the_absence_of_recent_preceding_chest_radiographs',
#  'interval_history',
#  'interval_monitoring',
#  'is_involved_in_those_bibasal_consolidations',
#  'ischemacxr',
#  'it_is_not_discernable',
#  'just_beyond_the_pylorus',
#  'knee_washout_surg',
#  'left_hemidaiphragm_elevation_surg',
#  'left_lower_lobe',
#  'limitations',
#  'line_tip_surg',
#  'lines',
#  'lines_and_tubes',
#  'liver_txp_surg',
#  'location_and_tip_of_picc_line_surg',
#  'locationcxr',
#  'lumen_nonhep_power_picc_deid_deid_contact_name',
#  'lungs',
#  'lungs_surg',
#  'main_report',
#  'major_fissure',
#  'mediastinum',
#  'mediastinum_and_hila',
#  'medications',
#  'mpression',
#  'multiple_lung_nodules_were_better_assessed_in_concurrent_chest_ct',
#  'multiple_pulmonary_abnormalities_include',
#  'multiple_seal_e',
#  'multitrauma',
#  'name',
#  'nchct',
#  'ndication',
#  'neck',
#  'negative_and_chronic_appearing',
#  'no_change_in_the_following',
#  'no_change_since_the_most_recent_prior_chest_radiograph_in',
#  'no_interval_change_of_the_multifocal_areas_of_airspace_opacification',
#  'no_section',
#  'note',
#  'notfications',
#  'notification',
#  'notifications',
#  'of_dose',
#  'of_picc_surg',
#  'of_the_process_but_decreased_size_separation_between_three_processes',
#  'omparison',
#  'on_deid_surg',
#  'one_cannot_tell_from_this_single_frontal_radiograph',
#  'one_view_of_the_chest',
#  'one_view_of_the_chest_and_abdomen',
#  'op_surg',
#  'opacities',
#  'opacities_are_grossly_unchanged',
#  'opinion',
#  'osseous_structures',
#  'other_findings',
#  'overload_surg',
#  'pa_and_ap_chest_radiograph',
#  'pa_and_lat',
#  'pa_and_lat_chest_radiograph',
#  'pa_and_lateral_chest',
#  'pa_and_lateral_chest_films',
#  'pa_and_lateral_chest_radiograph',
#  'pa_and_lateral_chest_radiographs',
#  'pa_and_lateral_chest_reviewed_in_the_absence_of_prior_chest_imaging',
#  'pa_and_lateral_chest_reviewed_in_the_absence_of_prior_chest_radiographs',
#  'pa_and_lateral_films_of_the_chest',
#  'pa_and_lateral_radiograph',
#  'pa_and_lateral_radiograph_of_the_chest',
#  'pa_and_lateral_radiographs_of_the_chest',
#  'pa_and_lateral_upright_chest_radiographs',
#  'pa_and_lateral_view_of_the_chest',
#  'pa_and_lateral_views_chest',
#  'pa_and_lateral_views_of_chest',
#  'pa_and_lateral_views_of_the_chest',
#  'pa_and_laterl_chest_radiograph',
#  'pa_lateral_views_of_the_chest',
#  'partially_imaged',
#  'patient_arrives',
#  'patient_arrives_for_portable_cxr_please_obtain_when_patient_reaches_sicu',
#  'patient_history',
#  'pcxr',
#  'pelvis',
#  'perform_at_deid_on_deid_per_thoracic_surgery_surg',
#  'performed_concurrently_and_reported_separately',
#  'performed_concurrently_but_reported_separately',
#  'performed_earlier_today',
#  'place_ends_in_the_mid_stomach_just_beyond_a_nasogastric_drainage_tube',
#  'placement_contact_name',
#  'placement_surg',
#  'placementct',
#  'planning_for_deid_surg',
#  'planning_surg',
#  'please_assess_for_any_abnormalities_surg',
#  'please_contact_name',
#  'please_eval_for_acute_process_surg',
#  'please_eval_for_interval_change',
#  'please_evaluate_line_placements_contact_name',
#  'please_evaluate_surg',
#  'please_note',
#  'please_surg',
#  'pleura',
#  'pleural_effusion',
#  'pleural_effusions_surg',
#  'pm_surg',
#  'pna_surg',
#  'pneumonia',
#  'pneumonia_surg',
#  'pneumonianchct',
#  'portable_ap_and_lateral_chest_radiograph',
#  'portable_ap_and_lateral_chest_radiographs',
#  'portable_ap_chest',
#  'portable_ap_chest_radiograph',
#  'portable_ap_chest_radiographs',
#  'portable_ap_frontal_chest_radiograph',
#  'portable_ap_frontal_view_of_the_chest',
#  'portable_ap_radiograph_of_the_chest',
#  'portable_ap_supine_chest_radiograph',
#  'portable_ap_upright_chest_radiograph',
#  'portable_ap_upright_chest_radiographs',
#  'portable_ap_upright_radiograph_of_the_chest',
#  'portable_ap_upright_view_of_the_chest',
#  'portable_ap_view_of_the_chest',
#  'portable_because_cannot_stand_surg',
#  'portable_chest',
#  'portable_chest_radiograph',
#  'portable_erect_frontal_chest_radiograph',
#  'portable_erect_radiograph',
#  'portable_frontal_chest',
#  'portable_frontal_chest_radiograph',
#  'portable_frontal_chest_radiographs',
#  'portable_frontal_view_of_the_chest',
#  'portable_pa_chest_radiograph',
#  'portable_radiograph',
#  'portable_radiograph_of_the_chest',
#  'portable_supine_ap_chest_radiograph',
#  'portable_supine_ap_view_of_the_chest',
#  'portable_supine_chest_radiograph',
#  'portable_supine_frontal_chest_radiograph',
#  'portable_supine_frontal_view_of_the_chest',
#  'portable_supine_radiograph_of_the_chest',
#  'portable_surg',
#  'portable_upright_ap_chest_radiograph',
#  'portable_upright_ap_view_of_the_abdomen',
#  'portable_upright_ap_view_of_the_chest',
#  'portable_upright_chest',
#  'portable_upright_chest_radiograph',
#  'portable_upright_frontal_chest_radiograph',
#  'portable_upright_frontal_view_of_the_chest',
#  'portable_upright_radiograph_chest',
#  'portable_upright_radiograph_of_the_chest',
#  'portalble_ap_chest_radiograph',
#  'position',
#  'positioning_contact_name',
#  'possible_pulmonary_process',
#  'postoperative_changes_including',
#  'postoperative_chest_radiograph',
#  'pre_op_surg',
#  'preliminary_report',
#  'preop_cxr_surg',
#  'preop_for_surgery_surg',
#  'preop_surg',
#  'present',
#  'prior_exam',
#  'procedure',
#  'procedure_details',
#  'process_surg',
#  'processess_preop_avr_surg',
#  'projection',
#  'pulmonary_edema_surg',
#  'pulmonary_hyperinflation_and_mild_coarsening_of_the_bronchovascular_markings',
#  'question_pna',
#  'radiograph',
#  'radiograph_surg',
#  'radiographs',
#  'radiologist_is_as_follows',
#  'radiolucencies_that_were_adjacent_to_the_left_cardiac_border_are_better',
#  'reason_for_exam',
#  'reason_for_examination',
#  'reason_for_indication',
#  'reason_for_the_exam',
#  'reason_fore_exam',
#  'reason_of_exam',
#  'recent_chest_xray_surg',
#  'recommedations',
#  'recommendation',
#  'recommendation(s)',
#  'recommendations',
#  'recommendations(s)',
#  'recommended',
#  'recommmendations',
#  'reference_exam',
#  'reference_examination',
#  'reference_findings',
#  'report',
#  'report_pls',
#  'reported_separately',
#  'repositioned_and_still_projects_in_the_mid_hemithorax',
#  'represent',
#  'requesting_cxr_to_assess_lung_fields_surg',
#  'resolution_of_ptx_surg',
#  'ribs',
#  'right',
#  'right_and_left_frontal_oblique_views_of_the_chest',
#  'right_chest_tube_questions_to_be_answered',
#  'right_lower_lung_opacity_has_increased',
#  'right_picc_line_tip_is_mild_position',
#  'right_ribs',
#  'right_shoulder_radiographs',
#  'ro_infectious_process_surg',
#  'ro_pna_surg',
#  'ro_ptx_surg',
#  'rxquestions_to_be_answered',
#  'semi',
#  'semi_erect_portable_chest_radiograph',
#  'semierect_ap_view_of_the_chest',
#  'semierect_portable_radiograph_of_the_chest',
#  'semiupright_portable_radiograph_of_the_chest',
#  'severe',
#  'sided_pneumothroax_sp_chest_tubequestions_to_be_answered',
#  'signs_of_volume_overload_surg',
#  'sin',
#  'since_deid_there_been_substantial_changes',
#  'since_prior_imaging_surg',
#  'since_the_prior_study',
#  'single_ap_chest_radiograph',
#  'single_ap_erect_portable_view_of_the_chest',
#  'single_ap_portable_chest_radiograph',
#  'single_ap_portable_view_of_the_chest',
#  'single_ap_radiographs',
#  'single_ap_upright_chest_radiograph',
#  'single_ap_upright_portable_chest_radiograph',
#  'single_ap_upright_view_of_the_chest',
#  'single_ap_view_of_the_chest',
#  'single_frontal_chest_radiograph',
#  'single_frontal_chest_radiographs',
#  'single_frontal_portable_supine_view_of_the_chest',
#  'single_frontal_portable_view_of_the_chest',
#  'single_frontal_view',
#  'single_frontal_view_of_the_chest',
#  'single_pa_view_of_the_chest',
#  'single_portable_ap_chest_radiograph',
#  'single_portable_ap_view_of_the_chest',
#  'single_portable_chest_radiograph',
#  'single_portable_frontal_view_of_the_chest',
#  'single_portable_radiograph',
#  'single_portable_upright_chest_radiograph',
#  'single_portable_upright_view_of_the_chest',
#  'single_portable_view_of_the_chest',
#  'single_supine_ap_portable_chest_radiograph',
#  'single_supine_portable_view_of_the_chest',
#  'single_upright_portable_chest_radiograph',
#  'single_upright_portable_view_of_the_chest',
#  'sp_chest_tube_removal',
#  'sp_pneumonectomy_eval_for_pna_surg',
#  'status',
#  'status_with_inability_to_be_weaned_from_the_vent',
#  'stenosiscxr',
#  'story',
#  'streak',
#  'studies',
#  'study',
#  'subduralct_ap',
#  'supine_ap_portable_chest_radiograph',
#  'supine_ap_view_of_the_chest',
#  'supine_chest_radiograph',
#  'supine_frontal_chest_radiograph',
#  'supine_frontal_view_of_the_chest',
#  'supine_portable_ap_chest_radiograph',
#  'supine_portable_chest',
#  'supine_portable_chest_radiograph',
#  'supine_portable_chest_radiographs',
#  'supine_portable_frontal_chest_radiograph',
#  'supine_portable_frontal_view_of_the_chest',
#  'supine_portable_radiograph',
#  'supine_portable_radiograph_of_the_chest',
#  'support_devices',
#  'support_lines_and_tubes_are_unchanged',
#  'surg',
#  'surgery',
#  'techique',
#  'technique',
#  'technique_and_findings',
#  'technique_pa_and_lateral_views_of_the_chest',
#  'the',
#  'the_arison',
#  'the_chin_is_flexed',
#  'the_comparison',
#  'the_compressing',
#  'the_differential_diagnosis_would_include',
#  'the_findings_were_recognized',
#  'the_following_support_devices_are_identified',
#  'the_or_tomorrow_for_angiogram_surg',
#  'there_is_active_pneumonia_depends_upon_clinical_circumstances',
#  'there_is_any_concern_with_findings_contact_name',
#  'three_views_of_the_chest',
#  'time',
#  'to_be_answered',
#  'to_r_scap_and_mult_left_rib_fractures',
#  'transfixing_an',
#  'transplant_surg',
#  'two_ap_views_of_the_chest',
#  'two_portable_ap_views_of_the_chest',
#  'two_portable_erect_views_of_the_chest',
#  'two_portable_frontal_radiographs',
#  'two_portable_views_of_the_chest',
#  'two_vies_of_the_chest',
#  'two_views_of_the_chest',
#  'two_views_of_the_chest_with_cone_downed_views_of_the_left_ribs',
#  'two_views_of_the_left_chest',
#  'two_views_of_the_thoracic_spine',
#  'type_of_exam',
#  'type_of_examination',
#  'type_of_the_examination',
#  'ultrasound',
#  'update',
#  'upright_ap_and_lateral_chest_radiograph',
#  'upright_ap_and_lateral_views_of_chest',
#  'upright_ap_and_lateral_views_of_the_chest',
#  'upright_ap_chest_radiograph',
#  'upright_ap_view_of_the_chest',
#  'upright_frontal_and_lateral_chest_radiographs',
#  'upright_frontal_and_lateral_views_of_the_chest',
#  'upright_frontal_chest_radiograph',
#  'upright_frontal_view_of_the_chest',
#  'upright_pa_and_lateral_views_of_the_chest',
#  'upright_pa_and_lateral_views_the_chest',
#  'upright_portable_ap_chest_radiograph',
#  'upright_portable_chest',
#  'upright_portable_chest_radiograph',
#  'upright_portable_radiograph_of_the_chest',
#  'volume_overload_surg',
#  'wbc_count',
#  'wet_read',
#  'wetread',
#  'wire_placementcth',
#  'with_dah_and_ild',
#  'with_ho_positive_ppdquestions_to_be_answered',
#  'work_up_surg',
#  'workup_surg',
#  'xray_surg',
#  'year_old_woman_with_sah_plan_for_angiogram_tomorrow_surg'}

# %% [markdown]
# ## Investigating empty files

# %% [markdown]
# According to my algorithm, only s54168089.txt is completely empty i.e. has no text. The ones that are in below list just don't have impressions and findings sections

# %%
total_files_to_read = glob.glob(in_dir + '*.txt')

# %%
len(reports_df)
# Out:
# 224671

# %%
len(total_files_to_read)
# Out:
# 224672

# %%
chexpert_files = glob.glob('/data/vision/polina/projects/chestxray/work_space_v2/report_processing/chexpert_labels/' + '*.csv')

# %%
def get_file_names(filelist):
    filenames = [os.path.splitext(os.path.basename(a))[0] for a in filelist]
    return filenames

# %%
total_filenames = get_file_names(total_files_to_read)
chexpert_filenames = get_file_names(chexpert_files)

# %%
empty_files = set(total_filenames) - set(chexpert_filenames)

# %%
with open('empty_files.txt', 'w') as empty_f:
    for filename in empty_files:
        empty_f.write(filename +'.txt'+ '\n')
# empty_files

# %% [markdown]
# The above files do not contain findings or impressions sections, and basically contain reason_for_examination sections.

# %%
print("The following files contain findings or impressions section. Warning: some of the finding or impression might actually be empty but because the word was present, the algorithm thought it was there")
for file in empty_files:
    report_dict = lm_utils.get_report_dictionary(in_res(file + '.txt'))
    if report_dict and ('findings' in report_dict['final_report'].keys() or 'impression' in report_dict['final_report'].keys()):
        print("File %s.txt"%file)
# Out:
# The following files contain findings or impressions section. Warning: some of the finding or impression might actually be empty but because the word was present, the algorithm thought it was there
# File s53822563.txt
# File s55884447.txt
# File s56869432.txt
# File s52197607.txt
# File s58393138.txt
# File s59094925.txt
# File s59363654.txt
# File s53801626.txt
# File s58851430.txt
# File s59954972.txt
# File s51704764.txt
# The file /data/vision/polina/projects/chestxray/data_v2/reports/s54168089.txt is empty
# File s53356173.txt
# File s55460408.txt
# File s58137144.txt
# File s53627605.txt
# File s51966946.txt
# File s55664890.txt
# File s50276465.txt
# File s57484509.txt
# File s53240872.txt
# File s50487727.txt
# File s58049533.txt
# File s59285278.txt
# File s51067117.txt
# File s55354071.txt
# File s53935525.txt
# File s59385570.txt
# File s54374353.txt
# File s50336284.txt
# File s50804446.txt
# File s59569833.txt
# File s58364589.txt
# File s59532776.txt
# File s53283173.txt
# File s58794078.txt
# File s59185554.txt
# File s51394967.txt
# File s59052974.txt
# File s52671410.txt
# File s55290247.txt
# File s59060030.txt

# %% [markdown]
# ## Various different tests

# %%
reports_df.iloc[0]['report']
# Out:
# {'final_report': {'chest': 'Frontal and lateral views',
#   'comparison': 'None.',
#   'examination': '',
#   'findings': 'The lungs are clear without focal consolidation. The lungs are relatively hyperinflated, suggesting underlying chronic obstructive pulmonary disease. No pleural effusion or pneumothorax is seen. The cardiac and mediastinal silhouettes are unremarkable.',
#   'impression': 'No acute cardiopulmonary process. If high clinical concern for pulmonary lesion, chest CT is more sensitive in detecting subtle lesions.',
#   'indication': 'History: M with failure to thrive and weight loss, history of smoking // Evaluate for mass',
#   'technique': 'Chest: Frontal and Lateral'}}

# %%
total_files_to_read = glob.glob(in_dir + '*.txt')
print('Total files to read:' , len(total_files_to_read) , ' from dir: ' , in_dir)
# Out:
# Total files to read: 224672  from dir:  /data/vision/polina/projects/chestxray/data_v2/reports/

# %%
file = in_res('s50000028.txt')
with open(file, 'r') as text_file:
    for line in text_file.readlines():
        line = line.strip()
        line = line.replace('_', '')
        print(line)
# Out:
# WET READ:   7:51 PM
# 6.2 x 5 cm mass projecting to the superior segment of the left lower lobe,
# concerning for malignancy particularly given calcified pleural plaques.
# Contrast enhanced CT recommended for further evaluation.  d/
#
# WET READ VERSION #1
#
# FINAL REPORT
# CLINICAL HISTORY:  Cough, evaluate for pneumonia.
#
# CHEST, PA AND LATERAL
#
# COMPARISON FILM:  .
#
# A mass is present in the superior segment of the left lower lobe and therefore
# malignancy must be considered.  Elsewhere, the left lung appears clear.  There
# is no effusion. Calcified pleural plaque is present in the right mid zone.
# The right lung appears clear.
#
# Some tracheal displacement to the right is present at the thoracic inlet
# probably due to thyroid, but lymph nodes should also be considered.
#
# IMPRESSION:  Left lung mass.  CT should be performed.

# %%
a = 'FINDINGS: sdjasjdja: jdsajdajs: adasdsas'
# m = re.search('(?<=.*:).*', a)
m = re.match('.*:.*', a) # check if the sentence contains quotes, most likely a section
section_name = a.split(':')[0]
m = re.search('(?<=%s:).*'%section_name, a)
# a.split(':')[0]
full_line = m.group(0).strip()

# %%
full_line
# Out:
# 'sdjasjdja: jdsajdajs: adasdsas'

# %%
lm_utils.get_report_dictionary(in_res('s50817290.txt'))
# Out:
# {'final_report': {'no_section': 'REASON FOR EXAMINATION: Hypoxemia. AP radiograph of the chest was reviewed in comparison to . The ET tube tip is approximately 3 cm above the carina. The NG tube tip is in the stomach. Heart size and mediastinum are unremarkable. Lungs are well aerated with unchanged scarring in the right apex, chronic as well as still present minimal bibasilar atelectasis better appreciated on the CT torso. Overall, no substantial interval change to explain hypoxemia has been demonstrated on the current radiograph.'}}

# %%
original_reports_df = reports_df.copy()

# %%
# filename = ''
# filename = original_reports_df.iloc[0]['filename']
filename = 's59159499.txt'

# %%
report = ''                                                                                            
origin_sec = []                                                                                        
report_dict = original_reports_df[original_reports_df['filename'] == filename]['report'].values[0]     
sections_to_find = ['finding', 'impression', 'conclusion', 'recommendation']                           
values_found = [] # a list of all values found within the dictionary; possibly a list of lists         
for section in sections_to_find:                                                                       
    keys_found = []                                                                                    
    sections_found = []                                                                                
    final_report = report_dict['final_report']                                                         
    for s in final_report.keys():                                                                      
        if section in s:                                                                               
            keys_found.append(s)                                                                       
            sections_found.append(section)                                                                    
    if len(keys_found) > 0:                                                                            
        values_needed = [final_report[key] for key in keys_found]                                      
        # only add the values for the non duplicated keys                                              
        for val in values_needed:                                                                      
            if val not in values_found:                                                                
                values_found.append(val)                                                               
        for sec in sections_found:                                                                     
            if sec not in origin_sec:                                                                  
                origin_sec.append(sec)                                                                 
for val in values_found:                                                                               
    if type(val) is list:                                                                              
        report += ' '.join(val) + ' '                                                                  
    else: 
        report += val + ' '                                                                            
 #if any('finding' in s for s in report_dict['final_report'].keys()) and report_dict['final_report']['findings']:
 #    origin_sec.append('findings')                                                                     
 #    report += report_dict['final_report']['findings'] + ' '.                                          
 #if 'impression' in report_dict['final_report'].keys() and report_dict['final_report']['impression']:  
 #    origin_sec.append('impression')                                                                   
 #    report += ' ' + report_dict['final_report']['impression']                                         
report = lm_utils.remove_whitespace(report)                                                                     
# reports.append(report)                                                                                 
# origin_sections.append(origin_sec)

# %%
report
# Out:
# ''

# %%
report_dict['final_report']
# Out:
# {'ap_chest_at_deid_and_compared_to_deid_for': 'Tip of the right PICC line is at a level 6.5 cm inferior to the carina, and would need to be withdrawn 3 cm to place it in the low SVC. Lungs clear and heart size normal. No pleural abnormality. Esophagus is mildly distended with air to the level of the carina. Cardiomediastinal and hilar silhouettes are otherwise unremarkable',
#  'comparison': '',
#  'findings': '',
#  'history': 'DEID -year-old man with infection.',
#  'impression': ''}

# %%
import re 
line = 'AP chest at DEID and compared to DEID for:'
re.match('^[a-zA-z]+(([\s]{1,2}|/)[a-zA-Z]+)*:.*', line) # is basically saying let all pass that have spaces between and ;
# Out:
# <_sre.SRE_Match object; span=(0, 42), match='AP chest at DEID and compared to DEID for:'>
